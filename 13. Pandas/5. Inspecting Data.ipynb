# %%
import pandas as pd

df=pd.read_excel("company_data.xlsx",sheet_name=0)

# Dimensions
print(df.shape)
print(len(df))

print(df.columns)
print(df.columns.to_list())
print(df.dtypes)
# Out:
# (505, 12)
# 505
# Index(['emp_id', 'name', 'age', 'gender', 'department', 'designation',
#        'salary', 'city', 'join_date', 'experience_years', 'rating', 'email'],
#       dtype='str')
# ['emp_id', 'name', 'age', 'gender', 'department', 'designation', 'salary', 'city', 'join_date', 'experience_years', 'rating', 'email']
# emp_id                int64
# name                    str
# age                 float64
# gender                  str
# department              str
# designation             str
# salary              float64
# city                    str
# join_date               str
# experience_years      int64
# rating              float64
# email                   str
# dtype: object

# %%
# Peeking at rows
# print(df.head())
# print(df.head(10))
# print(df.tail(10))
# print(df.sample(10))
# print(df.sample(frac=0.2))

# %%
# df.info()
# df.describe()
df.describe(include="int64")
# Out:
#             emp_id  experience_years
# count   505.000000        505.000000
# mean   1253.000000         17.768317
# std     145.925209         10.237448
# min    1001.000000          0.000000
# 25%    1127.000000          9.000000
# 50%    1253.000000         18.000000
# 75%    1379.000000         26.000000
# max    1505.000000         35.000000

# %%
df['department'].value_counts()
# df['department'].value_counts(normalize=True)
# df.nunique()
# df['department'].nunique()
# Out:
# np.int64(135)
