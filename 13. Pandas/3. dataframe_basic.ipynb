# %%
import pandas as pd

df=pd.DataFrame(
    {"product":["Laptop", "Mouse", "Monitor"],
     "price": [899.99, 29.99, 349.99],
     "stock": [15, 150, 40]
     },index=["p1","p2","p3"]
)

# List of dictionaries (each dict = one row)
df = pd.DataFrame([
    {"name": "Alice", "age": 30},
    {"name": "Bob", "age": 25},
    {"name": "Charlie", "age": 35},
])

# From a list of lists
df = pd.DataFrame([[1, "Alice", 85],
                   [2, "Bob", 90], 
                   [3, "Charlie", 78]], 
                   columns=["id", "name", "score"])

# Empty DataFrame (useful for building up data)
df = pd.DataFrame(columns=["id", "name", "score"])

print(df)
# Out:
# Empty DataFrame
# Columns: [id, name, score]
# Index: []
