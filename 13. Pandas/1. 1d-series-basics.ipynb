# %%
import pandas as pd

s=pd.Series([10,20,30,40],index=['a','b','c','d'])
# print(s)

# From Dictionary
s = pd.Series({"name": "Alice", "age": 30, "city": "Mumbai"})
print(s)
# Out:
# name     Alice
# age         30
# city    Mumbai
# dtype: object
