# %%
import pandas as pd
import numpy as np

employees = pd.read_csv("employees.csv")
departments = pd.read_csv("departments.csv")
projects = pd.read_csv("projects.csv")
emp_projects = pd.read_csv("employee_projects.csv")


result = pd.merge(
 employees,
 departments,
 left_on="department",
 right_on="dept_name",
 how="outer",
 indicator=True,
)
result[result["_merge"] == "left_only"]
# Out:
#      emp_id            name   age  gender   department designation    salary  \
# 0      1447  Vihaan Chauhan  31.0  Female  ENGINEERING      Senior   87702.0
# 136    1084    Deepak Verma  37.0  Female      FINANCE      Senior   87544.0
# 321    1483    Shreya Yadav  33.0    Male      PRODUCT        Lead   88645.0
# 387    1142  Reyansh Bansal  29.0    Male      SUPPORT     Manager  117619.0
# 388    1267   Aarav Chauhan  53.0  Female      SUPPORT      Senior   73024.0
# 497    1075    Sunita Desai  44.0    Male          NaN     Manager  125166.0
# 498    1111   Ritika Kapoor  47.0    Male          NaN   Associate   72942.0
# 499    1164      Kavya Iyer  52.0    Male          NaN      Senior   92504.0
# 500    1263    Rakesh Singh  24.0    Male          NaN      Senior   88624.0
# 501    1292     Nisha Yadav  25.0    Male          NaN        Lead   99427.0
# 502    1307     Riya Kapoor  35.0    Male          NaN     Manager  139493.0
# 503    1460      Kunal Iyer  25.0    Male          NaN        Lead   85204.0
# 504    1500   Sandeep Patel  24.0  Female          NaN     Manager  110504.0
#
#           city join_date  experience_years  rating  \
# 0         Pune  18-10-23                 8     3.5
# 136  Bangalore  05-03-18                15     2.9
# 321  Ahmedabad  22-11-20                13     3.7
# 387    Kolkata  05-04-15                 7     2.8
# 388  Hyderabad  04-08-25                30     3.9
# 497  Hyderabad  24-02-21                22     4.5
# 498     Jaipur  02-12-25                25     4.2
# 499    Kolkata  24-07-15                32     3.1
# 500       Pune  08-06-18                 4     3.1
# 501     Mumbai  12-10-22                 4     4.8
# 502      Delhi  15-11-23                12     3.1
# 503  Hyderabad  26-02-17                 1     3.8
# 504  Hyderabad  01-03-23                 1     2.5
#
#                           email  dept_id dept_name dept_head  budget_lakhs  \
# 0    vihaan.chauhan@company.com      NaN       NaN       NaN           NaN
# 136    deepak.verma@company.com      NaN       NaN       NaN           NaN
# 321    shreya.yadav@company.com      NaN       NaN       NaN           NaN
# 387  reyansh.bansal@company.com      NaN       NaN       NaN           NaN
# 388   aarav.chauhan@company.com      NaN       NaN       NaN           NaN
# 497    sunita.desai@company.com      NaN       NaN       NaN           NaN
# 498   ritika.kapoor@company.com      NaN       NaN       NaN           NaN
# 499      kavya.iyer@company.com      NaN       NaN       NaN           NaN
# 500    rakesh.singh@company.com      NaN       NaN       NaN           NaN
# 501     nisha.yadav@company.com      NaN       NaN       NaN           NaN
# 502     riya.kapoor@company.com      NaN       NaN       NaN           NaN
# 503      kunal.iyer@company.com      NaN       NaN       NaN           NaN
# 504   sandeep.patel@company.com      NaN       NaN       NaN           NaN
#
#     location     _merge
# 0        NaN  left_only
# 136      NaN  left_only
# 321      NaN  left_only
# 387      NaN  left_only
# 388      NaN  left_only
# 497      NaN  left_only
# 498      NaN  left_only
# 499      NaN  left_only
# 500      NaN  left_only
# 501      NaN  left_only
# 502      NaN  left_only
# 503      NaN  left_only
# 504      NaN  left_only
