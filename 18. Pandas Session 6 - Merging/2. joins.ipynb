# %%
import pandas as pd
import numpy as np

employees = pd.read_csv("employees.csv")
departments = pd.read_csv("departments.csv")

# result = pd.merge(
#     employees,
#     departments,
#     # left_on="department",
#     # right_on="department",
#     on="department", # When the key has same name
#     how="inner"
# )


# result = pd.merge(
#     employees,
#     departments,
#     left_on="department",
#     right_on="dept_name",
#     # on="department", # When the key has same name
#     how="left"
# )
# result = pd.merge(
#     employees,
#     departments,
#     left_on="department",
#     right_on="dept_name",
#     # on="department", # When the key has same name
#     how="right"
# )

result = pd.merge(
    employees,
    departments,
    left_on="department",
    right_on="dept_name",
    # on="department", # When the key has same name
    how="outer"
)
result.shape
# Out:
# (506, 17)
