# %%
import pandas as pd
import numpy as np

employees = pd.read_csv("employees.csv")
departments = pd.read_csv("departments.csv")
projects = pd.read_csv("projects.csv")
emp_projects = pd.read_csv("employee_projects.csv")

print(f"employees: {employees.shape}") 
print(f"departments: {departments.shape}") 
print(f"projects: {projects.shape}") 
print(f"emp_projects: {emp_projects.shape}")
# Out:
# employees: (505, 12)
# departments: (8, 5)
# projects: (20, 7)
# emp_projects: (595, 4)
