# %%
import pandas as pd

df = pd.read_csv("employees.csv")

# Drop columns
df.drop(columns=["email","age"], inplace=True)

# Drop rows
df.drop(index=[0,1,2],inplace=True)
df
# Out:
#      emp_id             name  gender   department designation    salary  \
# 3      1004       Rohan Shah    Male        Sales   Associate   72798.0
# 4      1005       Geeta Nair  Female  Engineering      Senior   91113.0
# 5      1006      Rahul Gupta    Male      Product          VP  209477.0
# 6      1007     Karan Mishra    Male  Engineering      Senior   82266.0
# 7      1008   Vivaan Chauhan  Female           HR   Associate   65792.0
# ..      ...              ...     ...          ...         ...       ...
# 500    1501  Pallavi Chauhan  Female  Engineering      Junior   55135.0
# 501    1502       Geeta Nair  Female  Engineering      Senior   91113.0
# 502    1503    Aditya Mishra  Female  Engineering      Junior   55060.0
# 503    1504    Shweta Pillai  Female        Sales      Senior   88299.0
# 504    1505    Rakesh Chopra    Male      Support     Manager  137886.0
#
#           city join_date  experience_years  rating
# 3       Mumbai  11-03-15                30     NaN
# ...
