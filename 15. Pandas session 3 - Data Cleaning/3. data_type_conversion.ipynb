# %%
import pandas as pd

df = pd.read_csv("employees.csv")

df["age"] = pd.to_numeric(df["age"])
df["age"] = df["age"].fillna(0).astype(int)

df["join_date"] = pd.to_datetime(df["join_date"])
df.dtypes
# Out:
# C:\Users\Code and Debug\AppData\Local\Temp\ipykernel_8120\229958050.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["join_date"] = pd.to_datetime(df["join_date"])
# emp_id                       int64
# name                           str
# age                          int64
# gender                         str
# department                     str
# designation                    str
# salary                     float64
# city                           str
# join_date           datetime64[us]
# experience_years             int64
# rating                     float64
# email                          str
# dtype: object

# %%
# The 'salary' column has -999 sentinel values. Replace them with NaN
# and then convert salary to numeric safely.
import numpy as np

df["salary"] = df["salary"].replace(-999,np.nan)
df["salary"] = pd.to_numeric(df["salary"],errors="coerce")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 5
#       1 # The 'salary' column has -999 sentinel values. Replace them with NaN
#       2 # and then convert salary to numeric safely.
#       3 import numpy as np
#       4
# ----> 5 df["salary"] = df["salary"].replace(-999,np.nan)
#       6 df["salary"]=df["salary"].fillna(0)
#       7 df["salary"] = pd.to_numeric(df["salary"],errors="coerce")
#       8 df
#
# File c:\Users\Code and Debug\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\Code and Debug\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File c:\Users\Code and Debug\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'salary'
