# %%
import pandas as pd

df = pd.read_csv("employees.csv")

df=df.rename(columns={
    "salary":"emp_salary",
    "join_date":"joining_date"
})
df.columns = df.columns.str.lower()
# df.columns = df.columns.str.replace(" ","-")
df.columns = df.columns.str.strip(" ").str.lower().str.replace(" ","-")
df
# Out:
#      emp_id            name   age  gender   department designation  \
# 0      1001    Kriti Saxena  33.0    Male  Engineering     Manager
# 1      1002     Aadhya Nair   NaN  Female  Engineering      Senior
# 2      1003   Bhavna Saxena  56.0    Male  Engineering      Intern
# 3      1004      Rohan Shah  51.0    Male        Sales   Associate
# 4      1005      Geeta Nair  45.0  Female  Engineering      Senior
# ..      ...             ...   ...     ...          ...         ...
# 510    1485     Varun Yadav  29.0    Male   Operations      Intern
# 511    1488    Ishaan Gupta  57.0    Male      Finance   Associate
# 512    1491     Ayaan Joshi  30.0    Male  Engineering      Senior
# 513    1493    Sai Kulkarni  39.0  Female      Product   Associate
# 514    1495  Ritika Chauhan  27.0  Female      Product      Senior
#
#      emp_salary       city join-date  experience_years  rating  \
# 0        -999.0      Delhi  25-04-24                10     3.5
# 1           NaN       Pune  24-05-16                15     NaN
# 2        -999.0       Pune  28-06-17                34     4.3
# 3       72798.0     Mumbai  11-03-15                30     NaN
# 4       91113.0    Kolkata  04-03-21                24     3.6
# ..          ...        ...       ...               ...     ...
# 510     21314.0       Pune  04-10-18                 5     3.7
# 511     52374.0     Mumbai  15-10-15                35     4.3
# 512     80129.0    Chennai  30-09-25                 9     4.8
# 513     48893.0    Chennai  13-08-21                19     2.7
# 514     74288.0  Ahmedabad  19-08-15                 3     4.2
#
#                           email
# 0      kriti.saxena@company.com
# 1       aadhya.nair@company.com
# 2     bhavna.saxena@company.com
# 3        rohan.shah@company.com
# 4        geeta.nair@company.com
# ..                          ...
# 510     varun.yadav@company.com
# 511    ishaan.gupta@company.com
# 512     ayaan.joshi@company.com
# 513    sai.kulkarni@company.com
# 514  ritika.chauhan@company.com
#
# [515 rows x 12 columns]
