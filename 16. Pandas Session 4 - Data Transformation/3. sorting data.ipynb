# %%
import pandas as pd
import numpy as np

df = pd.read_csv("employees.csv")

# new_df=df.sort_values("salary",ascending=False).reset_index(drop=True)

# Sort department A-Z, but with each salary high to low
new_df=df.sort_values(["department","salary"],ascending=[True,False])
new_df
# Out:
#      emp_id           name   age  gender   department designation    salary  \
# 450    1451   Aryan Thakur  33.0  Female  Engineering          VP  215521.0
# 498    1499   Karan Mishra  37.0    Male  Engineering          VP  213644.0
# 167    1168    Arun Kapoor  40.0    Male  Engineering          VP  207200.0
# 62     1063  Vishal Tiwari  40.0    Male  Engineering          VP  202502.0
# 201    1202      Kavya Rao  53.0  Female  Engineering    Director  179943.0
# ..      ...            ...   ...     ...          ...         ...       ...
# 291    1292    Nisha Yadav  25.0    Male          NaN        Lead   99427.0
# 163    1164     Kavya Iyer  52.0    Male          NaN      Senior   92504.0
# 262    1263   Rakesh Singh  24.0    Male          NaN      Senior   88624.0
# 459    1460     Kunal Iyer  25.0    Male          NaN        Lead   85204.0
# 110    1111  Ritika Kapoor  47.0    Male          NaN   Associate   72942.0
#
# ...
