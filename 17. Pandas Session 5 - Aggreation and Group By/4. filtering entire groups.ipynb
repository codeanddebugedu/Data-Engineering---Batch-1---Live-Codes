# %%
import pandas as pd
import numpy as np

df = pd.read_csv("employees.csv")
df["age"]=pd.to_numeric(df["age"])
df["age"]=df["age"].fillna(0).astype(int)

result=df.groupby("department").filter(lambda x:len(x)>50)
result=df.groupby("department").filter(lambda x:x["salary"].mean() > 86000)
result["department"].value_counts()

result=df.groupby("department").get_group("Engineering")["salary"].mean()
result
# Out:
# np.float64(86559.1052631579)
